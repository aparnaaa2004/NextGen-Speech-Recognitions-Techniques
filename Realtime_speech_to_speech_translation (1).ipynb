# %%
# !pip install pydub SpeechRecognition googletrans==4.0.0-rc1 gTTS


from pydub import AudioSegment
import speech_recognition as sr
from googletrans import Translator
from gtts import gTTS
from google.colab import files
import sys


print("Upload your audio file now...")

uploaded = files.upload()


if not uploaded:
    print("No file was uploaded. Please try again.")

    sys.exit()


filename = next(iter(uploaded))
print("File uploaded:", filename)


file_format = filename.split('.')[-1]

try:
    audio = AudioSegment.from_file(filename, format=file_format)
    wav_file = "converted.wav"
    audio.export(wav_file, format="wav")
    print("Converted to WAV.")
except Exception as e:
    print(f"Error during audio conversion: {e}")
    sys.exit()


recognizer = sr.Recognizer()

try:
    with sr.AudioFile(wav_file) as source:
        audio_data = recognizer.record(source)

    try:
        english_text = recognizer.recognize_google(audio_data)
        print("\nRecognized English Text:\n", english_text)


        translator = Translator()
        french_text = translator.translate(english_text, dest='fr').text
        print("\nFrench Translation:\n", french_text)


        tts = gTTS(french_text, lang='fr')
        french_audio_file = "french_output.mp3"
        tts.save(french_audio_file)


        files.download(french_audio_file)

    except sr.UnknownValueError:
        print("Speech recognition could not understand audio")
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")

except FileNotFoundError:
     print(f"Error: The converted WAV file '{wav_file}' was not found.")
except Exception as e:
     print(f"An unexpected error occurred during speech recognition: {e}")
# Out:
# ...
# Upload your audio file now...
#      <input type="file" id="files-0b429864-8d47-4081-9190-e9dc431a3d19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b429864-8d47-4081-9190-e9dc431a3d19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
